# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosalia-allie/Uncovering-Film-trends-through-EDA/blob/main/Overview_and_Data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Box office mojo data**

# %%
df0 = pd.read_csv('bom.movie_gross.csv.gz')
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df0.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# **The numbers data**

# %%
df1 = pd.read_csv('tn.movie_budgets.csv.gz')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df1.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# **IMDB data**

# %%
df2 = pd.read_csv('imdb.title.basics.csv.gz')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df2.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df3 = pd.read_csv('imdb.title.ratings.csv.gz')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
df3.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
movie_info_df = pd.read_csv('rt.movie_info.tsv.gz', sep='\t', quoting=3)
movie_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
movie_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  "This gritty, fast-paced, and innovative polic...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  "Illeana Douglas delivers a superb performance...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
movies_df = pd.read_csv('tmdb.movies.csv.gz')
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
movies_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %% [markdown]
# Data cleaning

# %% [markdown]
# Box office mojo data

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df0.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df0.columns = ['movie' if x == 'title' else x for x in df0.columns]

# %%
df0.year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
df0.foreign_gross.isna().sum()
# Out:
# np.int64(1350)

# %%
df0['foreign_gross'] = df0['foreign_gross'].apply(str).str.replace(",", "").astype(float)

# %%
df0['foreign_gross'] = df0['foreign_gross'].fillna(df0['foreign_gross'].median())
df0['domestic_gross'] = df0['domestic_gross'].fillna(df0['domestic_gross'].median())

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3387 non-null   float64
#  3   foreign_gross   3387 non-null   float64
#  4   year            3387 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 132.4+ KB

# %%
df0 = df0.dropna()

# %%
df0['total_gross'] = df0['foreign_gross'] + df0['domestic_gross']

# %%
studios_df = df0

# %%
studios_df.head()
# Out:
#                                          movie studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
# %store studios_df
# Out:
# Stored 'studios_df' (DataFrame)

# %% [markdown]
# the numbers data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df1.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
df1['year'] = df1['release_date'].apply(lambda x:x[7:12])

# %%
df1['production_budget'] = df1['production_budget'].apply(str).str.replace('$', '')
df1['production_budget'] = df1['production_budget'].apply(str).str.replace(',', '').astype(int)

# %%
df1['domestic_gross'] = df1['domestic_gross'].apply(str).str.replace('$', '')
df1['domestic_gross'] = df1['domestic_gross'].apply(str).str.replace(',', '').astype(int)

# %%
df1['worldwide_gross'] = df1['worldwide_gross'].apply(str).str.replace('$', '')
df1['worldwide_gross'] = df1['worldwide_gross'].apply(str).str.replace(',', '').astype(int)

# %%
df1['year'] = pd.to_numeric(df1['year']).astype(int)

# %%
df1 = df1[df1['year'] >= 2010]

# %%
numbers_df = df1
numbers_df.head()
# Out:
#    id  release_date                                        movie  \
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  worldwide_gross  year
# 1          410600000       241063875       1045663875  2011
# 2          350000000        42762350        149762350  2019
# 3          330600000       459005868       1403013963  2015
# 4          317000000       620181382       1316721747  2017
# 5          306000000       936662225       2053311220  2015

# %%
numbers_df.drop(columns=['id','release_date'], inplace=True)

# %%
numbers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2194 entries, 1 to 5780
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              2194 non-null   object
#  1   production_budget  2194 non-null   int64
#  2   domestic_gross     2194 non-null   int64
#  3   worldwide_gross    2194 non-null   int64
#  4   year               2194 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 102.8+ KB

# %%
numbers_df.head()
# Out:
#                                          movie  production_budget  \
# 1  Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                 Dark Phoenix          350000000
# 3                      Avengers: Age of Ultron          330600000
# 4            Star Wars Ep. VIII: The Last Jedi          317000000
# 5         Star Wars Ep. VII: The Force Awakens          306000000
#
#    domestic_gross  worldwide_gross  year
# 1       241063875       1045663875  2011
# 2        42762350        149762350  2019
# 3       459005868       1403013963  2015
# 4       620181382       1316721747  2017
# 5       936662225       2053311220  2015

# %%
# %store numbers_df
# Out:
# Stored 'numbers_df' (DataFrame)

# %%
df2_and_df3 = pd.merge(df2, df3, on='tconst', how='inner')
df2_and_df3.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
df2_and_df3['genres'].isna().sum()
# Out:
# np.int64(804)

# %%
df2_and_df3 = df2_and_df3.dropna(subset = ['genres'])

# %%
df2_and_df3['genres'] = [str(i) for i in df2_and_df3.genres]

# %%
df2_and_df3 = df2_and_df3.rename(columns={'primary_title':'movie'})

# %%
df2_and_df3.start_year.unique()
# Out:
# array([2013, 2019, 2018, 2017, 2010, 2011, 2012, 2015, 2016, 2014])

# %%
ratings_df = df2_and_df3.drop(columns=['tconst', 'runtime_minutes', 'original_title'])

# %%
ratings_df.head()
# Out:
#                              movie  start_year                      genres  \
# 0                        Sunghursh        2013          Action,Crime,Drama
# 1  One Day Before the Rainy Season        2019             Biography,Drama
# 4         The Wandering Soap Opera        2017        Comedy,Drama,Fantasy
# 5                          Bigfoot        2017             Horror,Thriller
# 6                  Joe Finds Grace        2017  Adventure,Animation,Comedy
#
#    averagerating  numvotes
# 0            7.0        77
# 1            7.2        43
# 4            6.5       119
# 5            4.1        32
# 6            8.1       263

# %%
genres_df = ratings_df.set_index('movie').genres.str.split(',',
            expand=True).stack().reset_index(level=1,
            drop=True).to_frame('genres')

# %%
genres_df.head()
# Out:
#                                     genres
# movie
# Sunghursh                           Action
# Sunghursh                            Crime
# Sunghursh                            Drama
# One Day Before the Rainy Season  Biography
# One Day Before the Rainy Season      Drama

# %%
# %store genres_df
# Out:
# Stored 'genres_df' (DataFrame)

# %%
ratings_df.describe()
# Out:
#          start_year  averagerating      numvotes
# count  37283.000000   37283.000000  37283.000000
# mean    2014.341121       6.236606     77.920715
# std        2.625324       1.494105     69.794409
# min     2010.000000       1.000000     14.000000
# 25%     2012.000000       5.300000     24.000000
# 50%     2014.000000       6.400000     49.000000
# 75%     2017.000000       7.300000    111.000000
# max     2019.000000      10.000000    289.000000

# %%
Q1 = ratings_df['numvotes'].quantile(0.25)
Q3 = ratings_df['numvotes'].quantile(0.75)
IQR = Q3 - Q1
print(Q1, Q3, IQR)
# Out:
# 24.0 111.0 87.0

# %%
ratings_df = ratings_df[ratings_df['numvotes'] >= Q1]

# %%
ratings_df = ratings_df[ratings_df['numvotes'] <= Q3]

# %%
ratings_df.describe()
# Out:
#          start_year  averagerating      numvotes
# count  19343.000000   19343.000000  19343.000000
# mean    2014.366179       6.325927     54.279274
# std        2.637133       1.444271     24.524540
# min     2010.000000       1.000000     24.000000
# 25%     2012.000000       5.500000     33.000000
# 50%     2014.000000       6.500000     48.000000
# 75%     2017.000000       7.300000     72.000000
# max     2019.000000       9.800000    111.000000

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19343 entries, 0 to 73836
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie          19343 non-null  object
#  1   start_year     19343 non-null  int64
#  2   genres         19343 non-null  object
#  3   averagerating  19343 non-null  float64
#  4   numvotes       19343 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 906.7+ KB

# %%
# %store ratings_df
# Out:
# Stored 'ratings_df' (DataFrame)

# %%
movie_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  "This gritty, fast-paced, and innovative polic...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  "Illeana Douglas delivers a superb performance...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
movies_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %% [markdown]
# **STUDIO ANALYSIS**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %store -r studios_df

# %%
studios_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3382 entries, 0 to 3386
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie           3382 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3382 non-null   float64
#  3   foreign_gross   3382 non-null   float64
#  4   year            3382 non-null   int64
#  5   total_gross     3382 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 185.0+ KB

# %%
studio_count = studios_df['studio'].value_counts()
studio_count = studio_count[:10]
plt.figure(figsize=(10,8))
sns.barplot(x=studio_count.index, y=studio_count.values, alpha=0.8)
plt.title('Top 10 Studios by Number of Movies Produced', fontsize=26)
plt.ylabel('Total Movies Produced', fontsize=16)
plt.xlabel('Studio', fontsize=16)
plt.show()

# %%
studios_grp = studios_df.groupby(['studio'])

# %%
mean_gross = studios_grp['total_gross'].mean()
mean_gross.sort_values(ascending=False, inplace=True)

# %%
mean_gross = mean_gross[:10,]
plt.figure(figsize=(10,8))
sns.barplot(x=mean_gross.index, y=mean_gross.values, alpha=0.9)
plt.title('Top 10 - Higher Average Gross Income', fontsize=24)
plt.ylabel('Mean Gross Income (expressed in 100M)', fontsize=16)
plt.xlabel('Studio', fontsize=16)
plt.show()

# %%
studios_df.loc[studios_df['studio'].isin(['HC', 'P/DW','GrtIndia'])]
# Out:
#                                    movie    studio  domestic_gross  \
# 4                    Shrek Forever After      P/DW     238700000.0
# 9               How to Train Your Dragon      P/DW     217600000.0
# 17                              Megamind      P/DW     148400000.0
# 71                   Dinner for Schmucks      P/DW      73000000.0
# 329       Transformers: Dark of the Moon      P/DW     352400000.0
# 333                      Kung Fu Panda 2      P/DW     165200000.0
# 338                        Puss in Boots      P/DW     149300000.0
# 734   Madagascar 3: Europe's Most Wanted      P/DW     216400000.0
# 752                Rise of the Guardians      P/DW     103400000.0
# 865                     A Thousand Words      P/DW      18500000.0
# 2764                      Wolf Warrior 2        HC       2700000.0
# 2796         Baahubali 2: The Conclusion  GrtIndia      20200000.0
#
#       foreign_gross  year   total_gross
# 4       513900000.0  2010  7.526000e+08
# 9       277300000.0  2010  4.949000e+08
# 17      173500000.0  2010  3.219000e+08
# 71       13800000.0  2010  8.680000e+07
# 329     771400000.0  2011  1.123800e+09
# 333     500400000.0  2011  6.656000e+08
# 338     405700000.0  2011  5.550000e+08
# 734     530500000.0  2012  7.469000e+08
# 752     203500000.0  2012  3.069000e+08
# 865       3600000.0  2012  2.210000e+07
# 2764    867600000.0  2017  8.703000e+08
# 2796    234000000.0  2017  2.542000e+08

# %%
correlation = mean_gross.corr(studio_count)
correlation
# Out:
# np.float64(-0.34479787354052405)

# %% [markdown]
# Making more movies does not mean making more money.
# Movie industry is mostly centralized in the USA.
# Interesting presence of China, India and Argentina in our Top 10's.
# Now that we understand our competition a little better, let's look at the numbers (notebook_2).

# %% [markdown]
# **THE NUMBERS ANALYSIS**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
genres_count = genres_df['genres'].value_counts()
genres_count = genres_count[:10,]
plt.figure(figsize=(12,8))
sns.barplot(x=genres_count.index, y=genres_count.values, alpha=0.8)
plt.title('Top 10 Most Produced Movie Genres', fontsize=26)
plt.ylabel('Total Movies Produced', fontsize=16)
plt.xlabel('Genre', fontsize=16)
plt.show()

# %%
genres_df.head()
# Out:
#                                     genres
# movie
# Sunghursh                           Action
# Sunghursh                            Crime
# Sunghursh                            Drama
# One Day Before the Rainy Season  Biography
# One Day Before the Rainy Season      Drama

# %%
numbers_df.head()
# Out:
#                                          movie  production_budget  \
# 1  Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                 Dark Phoenix          350000000
# 3                      Avengers: Age of Ultron          330600000
# 4            Star Wars Ep. VIII: The Last Jedi          317000000
# 5         Star Wars Ep. VII: The Force Awakens          306000000
#
#    domestic_gross  worldwide_gross  year
# 1       241063875       1045663875  2011
# 2        42762350        149762350  2019
# 3       459005868       1403013963  2015
# 4       620181382       1316721747  2017
# 5       936662225       2053311220  2015

# %%
numbers_by_genre = pd.merge(genres_df, numbers_df, on='movie', how='right')
numbers_by_genre.info()
numbers_by_genre.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              2480 non-null   object
#  1   genres             541 non-null    object
#  2   production_budget  2480 non-null   int64
#  3   domestic_gross     2480 non-null   int64
#  4   worldwide_gross    2480 non-null   int64
#  5   year               2480 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 116.4+ KB
#                                          movie genres  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides    NaN          410600000
# 1                                 Dark Phoenix    NaN          350000000
# 2                      Avengers: Age of Ultron    NaN          330600000
# 3            Star Wars Ep. VIII: The Last Jedi    NaN          317000000
# 4         Star Wars Ep. VII: The Force Awakens    NaN          306000000
#
#    domestic_gross  worldwide_gross  year
# 0       241063875       1045663875  2011
# 1        42762350        149762350  2019
# 2       459005868       1403013963  2015
# 3       620181382       1316721747  2017
# 4       936662225       2053311220  2015

# %%
numbers_by_genre['gross_profit'] = numbers_by_genre['worldwide_gross'] - numbers_by_genre['production_budget']

# %%
numbers_by_genre['worldwide_gross'].replace(0, 1)
# Out:
# 0       1045663875
# 1        149762350
# 2       1403013963
# 3       1316721747
# 4       2053311220
#            ...
# 2475             1
# 2476             1
# 2477             1
# 2478             1
# 2479             1
# Name: worldwide_gross, Length: 2480, dtype: int64

# %%
numbers_by_genre['gross_margin'] = (
    numbers_by_genre['gross_profit'].div(numbers_by_genre['worldwide_gross'])*100)

# %%
numbers_by_genre = numbers_by_genre[numbers_by_genre['gross_margin'] >= 0]
numbers_by_genre.info()
numbers_by_genre.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1423 entries, 0 to 2470
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              1423 non-null   object
#  1   genres             204 non-null    object
#  2   production_budget  1423 non-null   int64
#  3   domestic_gross     1423 non-null   int64
#  4   worldwide_gross    1423 non-null   int64
#  5   year               1423 non-null   int64
#  6   gross_profit       1423 non-null   int64
#  7   gross_margin       1423 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 100.1+ KB
#                                          movie genres  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides    NaN          410600000
# 2                      Avengers: Age of Ultron    NaN          330600000
# 3            Star Wars Ep. VIII: The Last Jedi    NaN          317000000
# 4         Star Wars Ep. VII: The Force Awakens    NaN          306000000
# 5                       Avengers: Infinity War    NaN          300000000
#
#    domestic_gross  worldwide_gross  year  gross_profit  gross_margin
# 0       241063875       1045663875  2011     635063875     60.733080
# 2       459005868       1403013963  2015    1072413963     76.436443
# 3       620181382       1316721747  2017     999721747     75.925058
# 4       936662225       2053311220  2015    1747311220     85.097242
# 5       678815482       2048134200  2018    1748134200     85.352522

# %%
numbers_by_genre['gross_profit'] = numbers_by_genre['worldwide_gross'] - numbers_by_genre['production_budget']

# %%
numbers_by_genre['worldwide_gross'].replace(0, 1)
# Out:
# 0       1045663875
# 1        149762350
# 2       1403013963
# 3       1316721747
# 4       2053311220
#            ...
# 2475             1
# 2476             1
# 2477             1
# 2478             1
# 2479             1
# Name: worldwide_gross, Length: 2480, dtype: int64

# %%
numbers_by_genre['gross_margin'] = (
    numbers_by_genre['gross_profit'].div(numbers_by_genre['worldwide_gross'])*100)

# %%
numbers_by_genre = numbers_by_genre[numbers_by_genre['gross_margin'] >= 0]
numbers_by_genre.info()
numbers_by_genre.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1423 entries, 0 to 2470
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              1423 non-null   object
#  1   genres             204 non-null    object
#  2   production_budget  1423 non-null   int64
#  3   domestic_gross     1423 non-null   int64
#  4   worldwide_gross    1423 non-null   int64
#  5   year               1423 non-null   int64
#  6   gross_profit       1423 non-null   int64
#  7   gross_margin       1423 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 100.1+ KB
#                                          movie genres  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides    NaN          410600000
# 2                      Avengers: Age of Ultron    NaN          330600000
# 3            Star Wars Ep. VIII: The Last Jedi    NaN          317000000
# 4         Star Wars Ep. VII: The Force Awakens    NaN          306000000
# 5                       Avengers: Infinity War    NaN          300000000
#
#    domestic_gross  worldwide_gross  year  gross_profit  gross_margin
# 0       241063875       1045663875  2011     635063875     60.733080
# 2       459005868       1403013963  2015    1072413963     76.436443
# 3       620181382       1316721747  2017     999721747     75.925058
# 4       936662225       2053311220  2015    1747311220     85.097242
# 5       678815482       2048134200  2018    1748134200     85.352522

# %%
genre_grp = numbers_by_genre.groupby(numbers_by_genre.genres)

# %%
mean_budget = genre_grp['production_budget'].mean()
mean_budget.sort_values(ascending=False, inplace=True)

# %%
mean_budget = mean_budget[:10,]
plt.figure(figsize=(12,8))
sns.barplot(x=mean_budget.index, y=mean_budget.values, alpha=0.9)
plt.title('Top 10 Genres with the Highest Avg Budget', fontsize=24)
plt.ylabel('Mean Movie Budget per Genre (expressed in 10M)', fontsize=16)
plt.xlabel('Genres', fontsize=16)
plt.show()

# %%
mean_profit = genre_grp['gross_profit'].mean()
mean_profit.sort_values(ascending=False, inplace=True)

# %%
mean_profit = mean_profit[:10,]
plt.figure(figsize=(12,8))
sns.barplot(x=mean_profit.index, y=mean_profit.values, alpha=0.9)
plt.title('Top 10 Genres - Highest Average Gross Profit', fontsize=24)
plt.ylabel('Mean Gross Profit (expressed in 100M)', fontsize=16)
plt.xlabel('Genres', fontsize=16)
plt.show()

# %%
correlation1 = mean_profit.corr(mean_budget)
correlation1
# Out:
# np.float64(0.8838975131190484)

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=mean_budget.values, y=mean_profit.values, alpha=0.9)
plt.title('Relationship between Budget & Gross Profit', fontsize=24)
plt.ylabel('Gross Profit (expressed in 100M)', fontsize=16)
plt.xlabel('Budget (expressed in 100M)', fontsize=16)
plt.show()

# %%
mean_margin = genre_grp['gross_margin'].mean().round(decimals=2)
mean_margin.sort_values(ascending=False, inplace=True)
mean_margin = mean_margin[:12,]
# %store mean_margin
# Out:
# Stored 'mean_margin' (Series)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=mean_margin.values, y=mean_margin.index, alpha=0.9)
plt.title('Top 12 Genres - Highest Return per $', fontsize=24)
plt.ylabel('Genres', fontsize=20)
plt.xlabel('Return per dollar (%)', fontsize=16)
plt.show()

# %%
correlation2 = mean_budget.corr(mean_margin)
correlation2
# Out:
# np.float64(-0.02820931777462675)

# %%
mean_margin = mean_margin[:10,]
plt.figure(figsize=(12,8))
sns.lineplot(x=mean_budget.values, y=mean_margin.values, alpha=0.9)
plt.title('Relationship between Budget & Gross Margin', fontsize=24)
plt.ylabel('Gross Margin (expressed in %)', fontsize=16)
plt.xlabel('Budget (expressed in 100M)', fontsize=16)
plt.show()

# %% [markdown]
# Drama, Documentary and Comedy are the Top 3 most produced genres.
# The Highest Average Budgets are between 4 and 10 million.
# The Top 12 Average Gross Profit Margin are above a 60% return.
# There's a positive correlation between Budget, Gross Profit and Gross Proftit Margin for our Top 10 Genres.
# Comedy, Adventure and Sci-Fi appear in all Top 10's.

# %% [markdown]
# **THE RATINGS ANALYSIS **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %store -r genres_df
# %store -r ratings_df
# %store -r mean_margin

# %%
ratings_by_genre = pd.merge(ratings_df, genres_df, on='movie', how='inner')

# %%
genre_grp = ratings_by_genre.groupby(ratings_by_genre.genres_y)

# %%
mean_rating = genre_grp['averagerating'].mean()
mean_rating.sort_values(ascending=False, inplace=True)

# %%
mean_rating = mean_rating[:12,]
plt.figure(figsize=(12,8))
sns.barplot(x=mean_rating.index, y=mean_rating.values, alpha=0.9)
plt.title('Top 12 Best Rated Genres', fontsize=24)
plt.ylabel('Mean Rating', fontsize=16)
plt.xlabel('Genres', fontsize=16)
plt.show()

# %%
correlation = mean_rating.corr(mean_margin)
correlation
# Out:
# np.float64(0.47730110875646165)

# %% [markdown]
# In our bar plot we saw how the Top 3 best rated Genres did not apper in our previous Top 10's.
# A slightly negative correlation between Ratings and Profit Margin reveal that most profitable does not always mean best rated.
# Music, Musical, Drama, Biography and Adventure are well rated and also highly profitable.

# %% [markdown]
# **END **
